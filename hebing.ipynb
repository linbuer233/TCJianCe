# %% [markdown]
# # 合并数据集

# %%
import xarray as xr

# %%
ds=xr.open_mfdataset('D:\\Project\\taifen\\data\\*_2017-2020_7-8.nc')
ds
# Out:
# D:\anaconda\envs\py310\lib\site-packages\xarray\core\indexing.py:1234: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]
# <xarray.Dataset>
# Dimensions:    (time: 992, longitude: 321, latitude: 241, level: 4)
# Coordinates:
#   * time       (time) datetime64[ns] 2017-07-01 ... 2020-08-31T18:00:00
#   * longitude  (longitude) float32 100.0 100.2 100.5 100.8 ... 179.5 179.8 180.0
#   * latitude   (latitude) float32 50.0 49.75 49.5 49.25 ... -9.5 -9.75 -10.0
#     expver     int32 1
#   * level      (level) int64 200 500 700 850
# Data variables:
# ...

# %%
ds.to_netcdf('../data/all.nc')
